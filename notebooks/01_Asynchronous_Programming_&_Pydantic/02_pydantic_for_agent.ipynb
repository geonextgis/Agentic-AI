# %% [markdown]
# ## What is Pydantic?
#
# **Pydantic** is a Python library used for **data validation, parsing, and settings management**. It allows developers to define the expected structure and data types of their data using Python type hints. Pydantic automatically checks incoming data, converts compatible values when possible, and provides clear validation errors when the data is invalid.
#
# Pydantic is widely used in modern Python applications, particularly in **API development, data processing, configuration management, and AI/ML applications**. It is also a core component of frameworks such as **FastAPI**.
#
# ### Key Features of Pydantic
#
# 1. **Data Validation**
#    Automatically validates data against predefined types and rules.
#
# 2. **Python Type Hints**
#    Uses standard Python type annotations such as `str`, `int`, `float`, `list`, and `dict` to define data structures.
#
# 3. **Automatic Type Conversion**
#    Converts compatible input values into the required Python types when possible.
#
# 4. **Custom Validation**
#    Developers can define custom validation rules for more complex requirements.
#
# 5. **Nested Data Models**
#    Supports complex and hierarchical data structures by allowing Pydantic models to contain other models.
#
# 6. **Clear Error Messages**
#    Provides detailed validation errors that make it easier to identify incorrect or missing data.
#
# 7. **Serialization and Deserialization**
#    Makes it easy to convert Python objects into dictionaries or JSON and reconstruct models from external data.
#
# 8. **Configuration Management**
#    Pydantic can be used to validate and manage application configuration and environment variables.
#
# 9. **JSON Schema Generation**
#    Models can be converted into JSON Schema, which is useful for API documentation and interoperability.
#
# ### Benefits of Pydantic
#
# - **Improves data reliability:** Ensures that applications work with correctly structured and validated data.
# - **Reduces boilerplate code:** Developers do not need to manually write repetitive type-checking logic.
# - **Easy to use:** It works naturally with Python's existing type-hinting system.
# - **Better error handling:** Validation errors clearly indicate what is wrong with the input.
# - **Improves maintainability:** Data structures are explicitly defined and easier for other developers to understand.
# - **Useful for APIs:** It is particularly effective for validating request and response data in frameworks such as FastAPI.
# - **Suitable for AI/ML applications:** It can enforce structured inputs and outputs when working with LLMs, agents, tools, and data pipelines.
# - **Supports complex data:** Nested models and custom validators make it suitable for sophisticated applications.

# %% [markdown]
# ## Problem without Pydantic

# %%
def add_patient_data(name: str, age: int):
    if type(name) == str and type(age) == int:
        if age > 0:
            print(name)
            print(age)
            print("Data added successfully to the database!")
        else:
            raise ValueError("Age cannot be negative.")
    else:
        raise TypeError("Invalid data type for name or age. Name should be a string and age should be an integer.")
    
def update_patient_data(name: str, age: int):
    if type(name) == str and type(age) == int:
        print(name)
        print(age)
        print("Data updated successfully in the database!")
        
    else:
        raise TypeError("Invalid data type for name or age. Name should be a string and age should be an integer.")

# %%
add_patient_data("Krish", 25)
# Out:
# Krish
# 25
# Data added successfully to the database!

# %%
# add_patient_data("Krish", "twenty five")

# %% [markdown]
# ## How to Use Pydantic
#
# 1. **Define a Pydantic model** that represents the **ideal schema** of the data.
#    - This includes the expected fields, their types, and any validation constraints (e.g., `gt=0` for positive numbers).
# 2. **Instantiate the model with raw input data** (usually a dictionary or JSON-like structure).
#    - Pydantic will automatically **validate** the data and **coerce** it into the correct Python types (if possible).
#    - If the data doesn't meet the model's requirements, Pydantic raises a `ValidationError`.
# 3. **Pass the validated model object** to functions or use it throughout your codebase.
#    - This ensures that every part of your program works with **clean, type-safe, and logically valid data**.

# %%
from pydantic import BaseModel

class PatientData(BaseModel):
    name: str
    age: int
    weight: float
    
def add_patient_data(patient: PatientData):
    print(patient.name)
    print(patient.age)
    print(patient.weight)
    print("Data added successfully to the database!")
    
def update_patient_data(patient: PatientData):
    print(patient.name)
    print(patient.age)
    print(patient.weight)
    print("Data updated successfully in the database!")

patient_data = {"name": "Halder", "age": 25, "weight": 72}

patient_1 = PatientData(**patient_data)

add_patient_data(patient_1)
# Out:
# Halder
# 25
# 72.0
# Data added successfully to the database!

# %%
update_patient_data(patient_1)
# Out:
# Halder
# 25
# 72.0
# Data updated successfully in the database!

# %%
patient_data = {"name": "Alex", "age": 25, "weight": 74}

patient_2 = PatientData(**patient_data)

update_patient_data(patient_2)
# Out:
# Alex
# 25
# 74.0
# Data updated successfully in the database!

# %% [markdown]
# ## Little Complex

# %%
from pydantic import BaseModel
from typing import List, Dict

class PatientData(BaseModel):
    name: str
    age: int
    weight: float
    married: bool
    allergies: List[str]
    contact: Dict[str, str]
    
def add_patient_data(patient: PatientData):
    print(patient.name)
    print(patient.age)
    print(patient.weight)
    print("Data added successfully to the database!")

def update_patient_data(patient=PatientData):
    print(patient.name)
    print(patient.age)
    print(patient.weight)
    print("Data updated successfully in the database!")

# %%
patient_data = {
    "name": "Krish",
    "age": 25,
    "weight": 72.5,
    "married": False,
    "allergies": ["peanuts", "shellfish"],
    "contact": {"email": "XYZ@gmail.com", "phone": "123-456-7890"}
}

patient_1_data = PatientData(**patient_data)
patient_1 = add_patient_data(patient_1_data)
# Out:
# Krish
# 25
# 72.5
# Data added successfully to the database!

# %% [markdown]
# ## Required and Optional Fields

# %%
from pydantic import BaseModel
from typing import List, Dict, Optional

class PatientData(BaseModel):
    name: str
    age: int
    weight: float
    married: bool = False
    allergies: Optional[List[str]] = None
    contact: Dict[str, str]
    
def add_patient_data(patient: PatientData):
    print(patient.name)
    print(patient.age)
    print(patient.weight)
    print(patient.married)
    print("Data added successfully to the database!")

def update_patient_data(patient=PatientData):
    print(patient.name)
    print(patient.age)
    print(patient.weight)
    print("Data updated successfully in the database!")

# %%
patient_data = {
    "name": "Krish",
    "age": 25,
    "weight": 72,
    "married": False,
    "allergies": ["peanuts", "shellfish"],
    "contact": {"email": "XYZ@gmail.com", "phone": "123-456-7890"}
}

patient_1_data = PatientData(**patient_data)
patient_1 = add_patient_data(patient_1_data)
# Out:
# Krish
# 25
# 72.0
# False
# Data added successfully to the database!

# %% [markdown]
# ## Data Validation

# %%
from pydantic import BaseModel, EmailStr, AnyUrl, Field
from typing import List, Dict, Optional

class PatientData(BaseModel):
    name: str = Field(max_length=50)
    email: EmailStr
    linkedin_url: AnyUrl
    age: int = Field(gt=0, lt=100)
    weight: float
    married: bool = False
    allergies: Optional[List[str]] = Field(max_length=5)
    contact: Dict[str, str]
    
def add_patient_data(patient: PatientData):
    print(patient.name)
    print(patient.age)
    print(patient.weight)
    print(patient.married)
    print("Data added successfully to the database!")

def update_patient_data(patient=PatientData):
    print(patient.name)
    print(patient.age)
    print(patient.weight)
    print("Data updated successfully in the database!")

# %%
patient_data = {
    "name": "Krish",
    "email": "krish@gmail.com",
    "linkedin_url": "https://www.linkedin.com/in/krishnagopal-halder/",
    "age": 25,
    "weight": 72,
    "married": False,
    "allergies": ["peanuts", "shellfish"],
    "contact": {"phone": "123-456-7890"}
}

patient_1_data = PatientData(**patient_data)
patient_1 = add_patient_data(patient_1_data)
# Out:
# Krish
# 25
# 72.0
# False
# Data added successfully to the database!

# %%
from pydantic import BaseModel, AnyUrl, EmailStr, Field
from typing import List, Dict, Optional, Annotated

class PatientData(BaseModel):
    name: Annotated[str, Field(max_length=50, title="Name of the patient", description="Give the name of the patient under 50 characters", examples=["Krish", "Abir"])]
    email: EmailStr
    linkedin_url: AnyUrl
    age: Annotated[int, Field(gt=0, lt=120, description="Age of the patient")]
    weight: Annotated[float, Field(default=None, description="Weight of the patient in kg")]
    married: Annotated[bool, Field(default=None, description="Is the patient married or not")]
    allergies: Annotated[Optional[List[str]], Field(default=None, max_length=5)]
    contact: Dict[str, str]
    
def add_patient_data(patient: PatientData):
    print(patient.name)
    print(patient.age)
    print(patient.weight)
    print(patient.married)
    print("Data added successfully to the database!")

def update_patient_data(patient=PatientData):
    print(patient.name)
    print(patient.age)
    print(patient.weight)
    print("Data updated successfully in the database!")

# %%
patient_data = {
    "name": "Krish",
    "email": "krish@gmail.com",
    "linkedin_url": "https://www.linkedin.com/in/krishnagopal-halder/",
    "age": 25,
    "weight": "72.05",
    "married": False,
    "allergies": ["peanuts", "shellfish"],
    "contact": {"phone": "123-456-7890"}
}

patient_1_data = PatientData(**patient_data)
patient_1 = add_patient_data(patient_1_data)
# Out:
# Krish
# 25
# 72.05
# False
# Data added successfully to the database!

# %% [markdown]
# ## Field Validator

# %%
from pydantic import BaseModel, AnyUrl, EmailStr, Field, field_validator
from typing import List, Dict, Optional, Annotated

class PatientData(BaseModel):
    name: str
    email: EmailStr
    age: int
    weight: float
    married: bool
    allergies: List[str]
    contact: Dict[str, str]
    
    @field_validator("email")
    @classmethod
    def email_validator(cls, value):
        valid_domains = ["sbi.com", "hdfc.com", "icici.com"]
        domain_name = value.split("@")[-1]
        
        if domain_name not in valid_domains:
            raise ValueError("Not a valid domain")
        
        return value
    
    @field_validator("name")
    @classmethod
    def transform_name(cls, value):
        return value.upper()
    
def add_patient_data(patient: PatientData):
    print(patient.name)
    print(patient.email)
    print(patient.age)
    print(patient.weight)
    print(patient.married)
    print(patient.allergies)
    print(patient.contact)
    print("Data added successfully to the database!")
    

patient_data = {
    "name": "Krish",
    "email": "Krish@sbi.com",
    "age": 25,
    "weight": 72,
    "married": False,
    "allergies": ["peanuts", "shellfish"],
    "contact": {"phone": "123-456-7890"}
}

patient_1 = PatientData(**patient_data)

add_patient_data(patient_1)
# Out:
# KRISH
# Krish@sbi.com
# 25
# 72.0
# False
# ['peanuts', 'shellfish']
# {'phone': '123-456-7890'}
# Data added successfully to the database!

# %% [markdown]
# ## Model Validator

# %%
from pydantic import BaseModel, EmailStr, AnyUrl, Field, field_validator, model_validator
from typing import List, Dict, Optional, Annotated

class PatientData(BaseModel):
    name: str
    email: EmailStr
    age: int
    weight: float
    married: bool
    allergies: List[str]
    contact: Dict[str, str]
    
    @model_validator(mode="after")
    def validate_emergency_contact(self):
        if self.age > 60 and "emergency" not in self.contact:
            raise ValueError("Patients older than 60 must have an emergency contact")
        return self

def add_patient_data(patient: PatientData):
    print(patient.name)
    print(patient.email)
    print(patient.age)
    print(patient.weight)
    print(patient.married)
    print(patient.allergies)
    print(patient.contact)
    print("Data added successfully to the database!")
    

patient_data = {
    "name": "Krish",
    "email": "Krish@sbi.com",
    "age": 70,
    "weight": 72,
    "married": False,
    "allergies": ["peanuts", "shellfish"],
    "contact": {"emergency": "123-456-7890"}
}

patient_1 = PatientData(**patient_data)

add_patient_data(patient_1)
# Out:
# Krish
# Krish@sbi.com
# 70
# 72.0
# False
# ['peanuts', 'shellfish']
# {'emergency': '123-456-7890'}
# Data added successfully to the database!

# %% [markdown]
# ## Computed Fields

# %%
from pydantic import BaseModel, EmailStr, AnyUrl, Field, field_validator, model_validator, computed_field
from typing import List, Dict, Optional, Annotated

class PatientData(BaseModel):
    name: str
    email: EmailStr
    age: int
    weight: float
    height: float
    married: bool
    allergies: List[str]
    contact: Dict[str, str]
    
    @computed_field
    @property
    def bmi(self) -> float:
        bmi = round(self.weight / (self.height ** 2), 2)
        return bmi

def add_patient_data(patient: PatientData):
    print(patient.name)
    print(patient.email)
    print(patient.age)
    print(patient.weight)
    print(patient.married)
    print(patient.allergies)
    print(patient.contact)
    print("BMI:", patient.bmi)
    print("Data added successfully to the database!")
    

patient_data = {
    "name": "Krish",
    "email": "Krish@sbi.com",
    "age": 25,
    "weight": 72,
    "height": 1.65,
    "married": False,
    "allergies": ["peanuts", "shellfish"],
    "contact": {"emergency": "123-456-7890"}
}

patient_1 = PatientData(**patient_data)

add_patient_data(patient_1)
# Out:
# Krish
# Krish@sbi.com
# 25
# 72.0
# False
# ['peanuts', 'shellfish']
# {'emergency': '123-456-7890'}
# BMI: 26.45
# Data added successfully to the database!

# %% [markdown]
# ## Nested Models

# %%
from pydantic import BaseModel

class Address(BaseModel):
    city: str
    state: str
    pin: str
    
class PatientData(BaseModel):
    name: str
    gender: str
    age: int
    address: Address
    
address_dict = {"city": "Muencheberg", "state": "Brandenburg", "pin": "53784"}
address = Address(**address_dict)

patient_dict = {
    "name": "Krish",
    "gender": "Male",
    "age": 25,
    "address": address
}
patient = PatientData(**patient_dict)

print(patient)
print(patient.name)
print(patient.address)
print(patient.address.city)
# Out:
# name='Krish' gender='Male' age=25 address=Address(city='Muencheberg', state='Brandenburg', pin='53784')
# Krish
# city='Muencheberg' state='Brandenburg' pin='53784'
# Muencheberg

# %% [markdown]
# ## Serialization

# %%
from pydantic import BaseModel

class Address(BaseModel):
    city: str
    state: str
    pin: str
    
class PatientData(BaseModel):
    name: str
    gender: str
    age: int
    address: Address
    
address_dict = {"city": "Muencheberg", "state": "Brandenburg", "pin": "53784"}
address = Address(**address_dict)

patient_dict = {
    "name": "Krish",
    "gender": "Male",
    "age": 25,
    "address": address
}
patient = PatientData(**patient_dict)

# temp = patient.model_dump()
temp = patient.model_dump_json()

print(temp)
print(type(temp))
# Out:
# {"name":"Krish","gender":"Male","age":25,"address":{"city":"Muencheberg","state":"Brandenburg","pin":"53784"}}
# <class 'str'>
